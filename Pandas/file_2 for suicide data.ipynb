# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv("suicide.csv")
df
# Out:
#       S#                      Date                   Islamic Date  \
# 0      1   Sunday-November 19-1995  25 Jumaada al-THaany 1416 A.H
# 1      2    Monday-November 6-2000           10 SHa`baan 1421 A.H
# 2      3      Wednesday-May 8-2002              25 safar 1423 A.H
# 3      4       Friday-June 14-2002     3 Raby` al-THaany 1423 A.H
# 4      5        Friday-July 4-2003     4 Jumaada al-awal 1424 A.H
# ..   ...                       ...                            ...
# 487  488       Monday-July-17-2017            22 Shawaal 1432 A.H
# 488  489       Monday-July-17-2017            22 Shawaal 1432 A.H
# 489  490       Monday-July-24-2017            29 Shawaal 1432 A.H
# 490  491   Saturday-August-12-2017                            NaN
# 491  492  Thursday-October-05-2017                            NaN
#
#     Blast Day Type Holiday Type         Time       City   Latitude  Longitude  \
# 0          Holiday      Weekend          NaN  Islamabad  33.718000    73.0718
# ...

# %%
df['Province'].unique()
# Out:
# array(['Capital', 'Sindh', 'Baluchistan', 'Punjab', 'FATA', 'KPK', 'AJK',
#        'Fata', 'Balochistan'], dtype=object)

# %%
df['Province'].replace(to_replace="Baluchistan",value="Balochistan",regex=True,inplace=True)

# %%
df['Province'].unique()
# Out:
# array(['Capital', 'Sindh', 'Balochistan', 'Punjab', 'FATA', 'KPK', 'AJK',
#        'Fata'], dtype=object)

# %%
df['Province'].replace(to_replace="FATA",value="Fata",regex=True,inplace=True)

# %%
df['Province'].unique()
# Out:
# array(['Capital', 'Sindh', 'Balochistan', 'Punjab', 'Fata', 'KPK', 'AJK'],
#       dtype=object)

# %%
df['City'].unique()
# Out:
# array(['Islamabad', 'Karachi', 'Karachi ', 'Quetta', 'Rawalpindi',
#        'North waziristan', 'Kohat', 'Attock ', 'Sialkot', 'Lahore ',
#        'Swat', 'Hangu', 'Bannu', 'North Waziristan', 'Lasbela',
#        'Malakand ', 'Peshawar', 'Peshawar ', 'D.I Khan ', 'Lakki Marwat',
#        'Tank', 'Islamabad ', 'Quetta ', 'Gujrat', 'Charsadda', 'Tank ',
#        'Swat ', 'D.I Khan', 'Kohat ', 'Kuram Agency ', 'Shangla ',
#        'Bajaur Agency', 'South Waziristan', 'Haripur', 'bannu',
#        'karachi ', 'Sargodha', 'Nowshehra', 'Charsadda ',
#        'Mohmand agency', 'Dara Adam Khel', 'Khyber Agency', 'Mardan',
#        'Bhakkar ', 'Orakzai Agency', 'Mohmand Agency', 'Buner',
#        'D.G Khan ', 'Pishin', 'Chakwal ', 'Lahore', 'Upper Dir',
#        'Muzaffarabad', 'swat', 'Totalai', 'Multan', 'D.G Khan',
#        'Lower Dir', 'Lakki marwat', 'Sudhanoti', 'Khyber Agency ',
#        'peshawar', 'Poonch', 'Mansehra', 'Karak', 'Mohmand Agency ',
# ...

# %%
df['City'].replace(to_replace="(peshawar)\s*|(Peshawar)\s*",value="Peshawar",regex=True,inplace=True)

# %%
df['City'].unique()
# Out:
# array(['Islamabad', 'Karachi', 'Karachi ', 'Quetta', 'Rawalpindi',
#        'North waziristan', 'Kohat', 'Attock ', 'Sialkot', 'Lahore ',
#        'Swat', 'Hangu', 'Bannu', 'North Waziristan', 'Lasbela',
#        'Malakand ', 'Peshawar', 'D.I Khan ', 'Lakki Marwat', 'Tank',
#        'Islamabad ', 'Quetta ', 'Gujrat', 'Charsadda', 'Tank ', 'Swat ',
#        'D.I Khan', 'Kohat ', 'Kuram Agency ', 'Shangla ', 'Bajaur Agency',
#        'South Waziristan', 'Haripur', 'bannu', 'karachi ', 'Sargodha',
#        'Nowshehra', 'Charsadda ', 'Mohmand agency', 'Dara Adam Khel',
#        'Khyber Agency', 'Mardan', 'Bhakkar ', 'Orakzai Agency',
#        'Mohmand Agency', 'Buner', 'D.G Khan ', 'Pishin', 'Chakwal ',
#        'Lahore', 'Upper Dir', 'Muzaffarabad', 'swat', 'Totalai', 'Multan',
#        'D.G Khan', 'Lower Dir', 'Lakki marwat', 'Sudhanoti',
#        'Khyber Agency ', 'Poonch', 'Mansehra', 'Karak', 'Mohmand Agency ',
# ...

# %%
df['City'].replace(to_replace="(karachi)\s*|(Karachi)\s*",value="Karachi",regex=True,inplace=True)

# %%
df['City'].unique()
# Out:
# array(['Islamabad', 'Karachi', 'Quetta', 'Rawalpindi', 'North waziristan',
#        'Kohat', 'Attock ', 'Sialkot', 'Lahore ', 'Swat', 'Hangu', 'Bannu',
#        'North Waziristan', 'Lasbela', 'Malakand ', 'Peshawar',
#        'D.I Khan ', 'Lakki Marwat', 'Tank', 'Islamabad ', 'Quetta ',
#        'Gujrat', 'Charsadda', 'Tank ', 'Swat ', 'D.I Khan', 'Kohat ',
#        'Kuram Agency ', 'Shangla ', 'Bajaur Agency', 'South Waziristan',
#        'Haripur', 'bannu', 'Sargodha', 'Nowshehra', 'Charsadda ',
#        'Mohmand agency', 'Dara Adam Khel', 'Khyber Agency', 'Mardan',
#        'Bhakkar ', 'Orakzai Agency', 'Mohmand Agency', 'Buner',
#        'D.G Khan ', 'Pishin', 'Chakwal ', 'Lahore', 'Upper Dir',
#        'Muzaffarabad', 'swat', 'Totalai', 'Multan', 'D.G Khan',
#        'Lower Dir', 'Lakki marwat', 'Sudhanoti', 'Khyber Agency ',
#        'Poonch', 'Mansehra', 'Karak', 'Mohmand Agency ',
#        'South waziristan', 'lakki marwat', 'Swabi ', 'Dara Adam khel',
# ...
