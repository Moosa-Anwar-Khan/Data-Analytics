# %%
import pandas as pd
import numpy as np
myfile = pd.read_csv("C:\\Users\\hp\\Desktop\\pyFile\\nfl.csv")
df = pd.DataFrame(myfile)
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (25,51) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3  2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4  2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
#
#    PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 0           0.0         TEN  ...       NaN     0.485675     0.514325
# 1           7.0         PIT  ...  1.146076     0.546433     0.453567
# 2          37.0         PIT  ...       NaN     0.551088     0.448912
# ...

# %%
df.shape
# Out:
# (362447, 102)

# %%
missingVals = df.isnull().sum()
print(missingVals[:20])
# Out:
# Date                 0
# GameID               0
# Drive                0
# qtr                  0
# down             54218
# time               188
# TimeUnder            0
# TimeSecs           188
# PlayTimeDiff       374
# SideofField        450
# yrdln              723
# yrdline100         723
# ydstogo              0
# ydsnet               0
# GoalToGo           723
# FirstDown        25597
# posteam          21979
# DefensiveTeam    21979
# desc                 2
# PlayAttempted        0
# dtype: int64

# %%
missing = df.isnull().sum()
cells = np.product(df.shape)
miss = missing.sum()
per = (miss/cells)*100
print(per)
# Out:
# 24.85847694188906

# %%
miss = df.isnull().sum()
print(miss[20:30])
# Out:
# Yards.Gained          0
# sp                    0
# Touchdown             0
# ExPointResult    353399
# TwoPointConv     361919
# DefTwoPoint      362433
# Safety                0
# Onsidekick            0
# PuntResult       342560
# PlayType              0
# dtype: int64

# %%
drpRows = df.dropna()
print(drpRows)
# Out:
# Empty DataFrame
# ...

# %%
drpCols = df.dropna(axis=1)
drpCols
# Out:
#               Date      GameID  Drive  qtr  TimeUnder  ydstogo  ydsnet  \
# 0       2009-09-10  2009091000      1    1         15        0       0
# 1       2009-09-10  2009091000      1    1         15       10       5
# 2       2009-09-10  2009091000      1    1         15        5       2
# 3       2009-09-10  2009091000      1    1         14        8       2
# 4       2009-09-10  2009091000      1    1         14        8       2
# ...            ...         ...    ...  ...        ...      ...     ...
# 362442  2017-01-01  2017010102     20    4          1       10      35
# 362443  2017-01-01  2017010102     20    4          1        0      35
# 362444  2017-01-01  2017010102     21    4          1        0       0
# 362445  2017-01-01  2017010102     21    4          1       10      -1
# 362446  2017-01-01  2017010102     21    4          0        0      -1
#
#         PlayAttempted  Yards.Gained  sp  ...  Timeout_Indicator  Timeout_Team  \
# ...

# %%
df.fillna(method="bfill").fillna(0).head()
# Out:
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   1.0  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3  2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4  2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
#
#    PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 0           0.0         TEN  ...  1.146076     0.485675     0.514325
# 1           7.0         PIT  ...  1.146076     0.546433     0.453567
# 2          37.0         PIT  ... -5.031425     0.551088     0.448912
# 3          41.0         PIT  ... -5.031425     0.510793     0.489207
# 4           8.0         PIT  ...  0.163935     0.461217     0.538783
#
#    Home_WP_post  Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# ...
